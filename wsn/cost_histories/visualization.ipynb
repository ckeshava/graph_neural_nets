# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('../h_2', 'rb') as fp:
    h_1 = pickle.load(fp)
    
# with open('h_2_g_1000', 'rb') as fp:
#     h_2 = pickle.load(fp)

# %%
plt.plot(h_1)
plt.xlabel('Number of Graphs')
plt.ylabel('Mean Squared Error')
plt.title('Learning Curve')
plt.show()
