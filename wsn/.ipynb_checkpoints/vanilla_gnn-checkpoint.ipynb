# %%
import numpy as np
import tensorflow as tf
import etp as etp
import calculate_virtual_coordinates as cvc
import matplotlib.pyplot as plt

from random import seed
from random import randint
seed(23)

C = 5 # maximum number of anchors
H = 500 # size of hidden filters
F = 2 # Final dimension of coordinates
random_seed = 23
radius = 1 # extent of possible communication
MAX_NODES = 1000
learning_rate = 0.7
epochs = 1000
display_cost_period = 200

# %%
def plot_learning(cost_history):
    plt.plot(cost_history)
    plt.xlabel('Epochs')
    plt.ylabel('Mean Squared Error')
    plt.title('Learning Curve')
    plt.show()

# %%
g = tf.Graph()

with g.as_default():
    tf.set_random_seed(random_seed)
    W_0 = tf.Variable(tf.truncated_normal(shape=(C, H),
                                      mean=0.0,
                                      stddev=0.1,
                                      dtype=tf.float32,
                                      seed=random_seed))
    
    W_1 = tf.Variable(tf.truncated_normal(shape=(H, F),
                                  mean=0.0,
                                  stddev=0.1,
                                  dtype=tf.float32,
                                  seed=random_seed))
    

    input_layer = tf.placeholder(tf.float32, [None, C], # INPUT: num_of_nodes X VC_values
                                 name='input')
    
    physical_coordinates = tf.placeholder(tf.float32, [None, F], # INPUT: num_of_nodes X geographic_coordinates
                                 name='phy_coord')
    
    adj = tf.placeholder(tf.float32, [None, None], # INPUT: num_of_nodes X num_of_nodes
                                 name='adj')
    
    A_caret = tf.placeholder(tf.float32, [None, None], # INPUT: num_of_nodes X num_of_nodes
                                 name='A_caret')

    
    out_1 = tf.matmul(tf.matmul(A_caret, input_layer), W_0)
    out_2 = tf.matmul(tf.matmul(A_caret, out_1), W_1)
    
    
#     cost = etp.get_best_etp(out_2, physical_coordinates)
#     cost = etp.get_best_etp(out_2, physical_coordinates)
    
    cost = tf.losses.mean_squared_error(out_2, physical_coordinates)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)
# Out:
# WARNING:tensorflow:From /home/keshava/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/keshava/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/losses/losses_impl.py:667: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
cost_history = []
with tf.Session(graph=g) as sess:
    # `sess.graph` provides access to the graph used in a `tf.Session`.
    writer = tf.summary.FileWriter("/tmp/log/...", sess.graph)

    # Perform your computation...
    for i in range(epochs):
        init_op = tf.global_variables_initializer()
        sess.run(init_op)
        
#         phy_coord, inps = cvc.get_VC(randint(10, MAX_NODES))
        phy_coord, inps = cvc.get_VC(randint(10, MAX_NODES))
        adj_matrix = cvc.get_adj(phy_coord)
        A_caret_matrix = cvc.normalize_adj(adj_matrix + np.eye(adj_matrix.shape[0]))
        
        print('Calculated all the inputs')

        curr_cost = sess.run(cost, feed_dict={input_layer: inps,
                                        physical_coordinates: phy_coord,
                                        adj: adj_matrix,
                                        A_caret: A_caret_matrix})

        
        cost_history.append(curr_cost)
        if not i%display_cost_period:
            plot_learning(cost_history)
            
        print('Epoch: {}\t cost: {}'.format(i, curr_cost))
        
        
        
            

    writer.close()
# Out:
# Calculated all the inputs
# Epoch: 0	 cost: 0.12848488986492157
# Calculated all the inputs
# Epoch: 1	 cost: 0.3116539418697357
# Calculated all the inputs
# Epoch: 2	 cost: 0.06999297440052032
# Calculated all the inputs
# Epoch: 3	 cost: 0.3606743812561035
# Calculated all the inputs
# Epoch: 4	 cost: 0.28965410590171814
# Calculated all the inputs
# Epoch: 5	 cost: 0.2927723526954651
# Calculated all the inputs
# Epoch: 6	 cost: 0.23784811794757843
# Calculated all the inputs
# Epoch: 7	 cost: 5.352062702178955
# Calculated all the inputs
# Epoch: 8	 cost: 1.8143136501312256
# Calculated all the inputs
# Epoch: 9	 cost: 0.5291634798049927
# Calculated all the inputs
# Epoch: 10	 cost: 0.6062503457069397
# Calculated all the inputs
# Epoch: 11	 cost: 0.2881340980529785
# Calculated all the inputs
# Epoch: 12	 cost: 0.43535345792770386
# Calculated all the inputs
# Epoch: 13	 cost: 0.1635330617427826
# Calculated all the inputs
# Epoch: 14	 cost: 0.17355763912200928
# Calculated all the inputs
# Epoch: 15	 cost: 0.2130274474620819
# Calculated all the inputs
# Epoch: 16	 cost: 2.458543300628662
# Calculated all the inputs
# Epoch: 17	 cost: 0.41206321120262146
# Calculated all the inputs
# Epoch: 18	 cost: 0.24285449087619781
# Calculated all the inputs
# Epoch: 19	 cost: 7.370568752288818
# Calculated all the inputs
# Epoch: 20	 cost: 0.40583938360214233
# Calculated all the inputs
# Epoch: 21	 cost: 0.7436656355857849
# Calculated all the inputs
# Epoch: 22	 cost: 0.1255326271057129
# Calculated all the inputs
# Epoch: 23	 cost: 0.1990823894739151
# Calculated all the inputs
# Epoch: 24	 cost: 2.2726571559906006
# Calculated all the inputs
# Epoch: 25	 cost: 0.2700454294681549
# Calculated all the inputs
# Epoch: 26	 cost: 3.2887649536132812
# Calculated all the inputs
# Epoch: 27	 cost: 0.10894262045621872
# Calculated all the inputs
# Epoch: 28	 cost: 0.21656113862991333
# Calculated all the inputs
# Epoch: 29	 cost: 0.184843048453331
# Calculated all the inputs
# Epoch: 30	 cost: 6.582747936248779
# Calculated all the inputs
# Epoch: 31	 cost: 0.1981150209903717
# Calculated all the inputs
# Epoch: 32	 cost: 0.36490598320961
# Calculated all the inputs
# Epoch: 33	 cost: 0.3607945740222931
# Calculated all the inputs
# Epoch: 34	 cost: 0.18290956318378448
# Calculated all the inputs
# Epoch: 35	 cost: 0.9006213545799255
# Calculated all the inputs
# Epoch: 36	 cost: 0.10263990610837936
# Calculated all the inputs
# Epoch: 37	 cost: 0.34345361590385437
# Calculated all the inputs
# Epoch: 38	 cost: 0.7959683537483215
# Calculated all the inputs
# Epoch: 39	 cost: 0.38653120398521423
# Calculated all the inputs
# Epoch: 40	 cost: 1.8810538053512573
# Calculated all the inputs
# Epoch: 41	 cost: 1.0134135484695435
# Calculated all the inputs
# Epoch: 42	 cost: 0.5186551213264465
# Calculated all the inputs
# Epoch: 43	 cost: 0.6656160354614258
# Calculated all the inputs
# Epoch: 44	 cost: 1.3337732553482056
# Calculated all the inputs
# Epoch: 45	 cost: 0.17024379968643188
# Calculated all the inputs
# Epoch: 46	 cost: 0.5436075329780579
# Calculated all the inputs
# Epoch: 47	 cost: 0.09627369791269302
# Calculated all the inputs
# Epoch: 48	 cost: 0.24338997900485992
# Calculated all the inputs
# Epoch: 49	 cost: 0.4919328987598419
# Calculated all the inputs
# Epoch: 50	 cost: 1.1977392435073853
# Calculated all the inputs
# Epoch: 51	 cost: 0.21149133145809174
# Calculated all the inputs
# Epoch: 52	 cost: 0.3475125730037689
# Calculated all the inputs
# Epoch: 53	 cost: 0.5632166266441345
# Calculated all the inputs
# Epoch: 54	 cost: 0.9877996444702148
# Calculated all the inputs
# Epoch: 55	 cost: 0.24064694344997406
# Calculated all the inputs
# Epoch: 56	 cost: 0.3505224287509918
# Calculated all the inputs
# Epoch: 57	 cost: 0.24152043461799622
# Calculated all the inputs
# Epoch: 58	 cost: 4.357110500335693
# Calculated all the inputs
# Epoch: 59	 cost: 0.36047324538230896
# Calculated all the inputs
# Epoch: 60	 cost: 0.48582562804222107
# Calculated all the inputs
# Epoch: 61	 cost: 1.4390860795974731
# Calculated all the inputs
# Epoch: 62	 cost: 0.66897052526474
# Calculated all the inputs
# Epoch: 63	 cost: 0.09987399727106094
# Calculated all the inputs
# Epoch: 64	 cost: 0.10189468413591385
# Calculated all the inputs
# Epoch: 65	 cost: 0.598343551158905
# Calculated all the inputs
# Epoch: 66	 cost: 0.4622384011745453
# Calculated all the inputs
# Epoch: 67	 cost: 0.7754607796669006
# Calculated all the inputs
# Epoch: 68	 cost: 0.37669286131858826
# Calculated all the inputs
# Epoch: 69	 cost: 0.544433057308197
# Calculated all the inputs
# Epoch: 70	 cost: 0.1827625036239624
# Calculated all the inputs
# Epoch: 71	 cost: 0.40346279740333557
# Calculated all the inputs
# Epoch: 72	 cost: 1.6789151430130005
# Calculated all the inputs
# Epoch: 73	 cost: 0.3210921287536621
# Calculated all the inputs
# Epoch: 74	 cost: 0.18988750874996185
# Calculated all the inputs
# Epoch: 75	 cost: 0.8206635117530823
# Calculated all the inputs
# Epoch: 76	 cost: 0.38814109563827515
# Calculated all the inputs
# Epoch: 77	 cost: 0.854433536529541
# Calculated all the inputs
# Epoch: 78	 cost: 1.1471080780029297
# Calculated all the inputs
# Epoch: 79	 cost: 0.2759958505630493
# Calculated all the inputs
# Epoch: 80	 cost: 3.611274242401123
# Calculated all the inputs
# Epoch: 81	 cost: 2.3869855403900146
# Calculated all the inputs
# Epoch: 82	 cost: 2.423107385635376
# Calculated all the inputs
# Epoch: 83	 cost: 0.2625913918018341
# Calculated all the inputs
# Epoch: 84	 cost: 9.589703559875488
# Calculated all the inputs
# Epoch: 85	 cost: 0.7169509530067444
# Calculated all the inputs
# Epoch: 86	 cost: 0.5110329389572144
# Calculated all the inputs
# Epoch: 87	 cost: 0.08264985680580139
# Calculated all the inputs
# Epoch: 88	 cost: 3.000070571899414
# Calculated all the inputs
# Epoch: 89	 cost: 0.1875932812690735
# Calculated all the inputs
# Epoch: 90	 cost: 0.3020232915878296
# Calculated all the inputs
# Epoch: 91	 cost: 1.3381450176239014
# Calculated all the inputs
# Epoch: 92	 cost: 0.183871328830719
# Calculated all the inputs
# Epoch: 93	 cost: 0.8074256181716919
# Calculated all the inputs
# Epoch: 94	 cost: 0.29596665501594543
# Calculated all the inputs
# Epoch: 95	 cost: 0.06611979752779007
# Calculated all the inputs
# Epoch: 96	 cost: 0.35940223932266235
# Calculated all the inputs
# Epoch: 97	 cost: 0.3254951536655426
# Calculated all the inputs
# Epoch: 98	 cost: 0.2639845013618469
# Calculated all the inputs
# Epoch: 99	 cost: 0.23395000398159027
# Calculated all the inputs
# Epoch: 100	 cost: 0.1901615858078003
# Calculated all the inputs
# Epoch: 101	 cost: 4.65413236618042
# Calculated all the inputs
# Epoch: 102	 cost: 0.6706433296203613
# Calculated all the inputs
# Epoch: 103	 cost: 0.47642260789871216
# Calculated all the inputs
# Epoch: 104	 cost: 0.3786819577217102
# Calculated all the inputs
# Epoch: 105	 cost: 0.5179818272590637
# Calculated all the inputs
# Epoch: 106	 cost: 2.381051778793335
# Calculated all the inputs
# Epoch: 107	 cost: 0.6234404444694519
# Calculated all the inputs
# Epoch: 108	 cost: 0.35538041591644287
# Calculated all the inputs
# Epoch: 109	 cost: 0.38897064328193665
# Calculated all the inputs
# Epoch: 110	 cost: 0.15352191030979156
# Calculated all the inputs
# Epoch: 111	 cost: 0.3220367133617401
# Calculated all the inputs
# Epoch: 112	 cost: 0.11324195563793182
# Calculated all the inputs
# Epoch: 113	 cost: 0.11898443847894669
# Calculated all the inputs
# Epoch: 114	 cost: 0.24016955494880676
# Calculated all the inputs
# Epoch: 115	 cost: 0.5102709531784058
# Calculated all the inputs
# Epoch: 116	 cost: 0.16803158819675446
# Calculated all the inputs
# Epoch: 117	 cost: 0.2432253211736679
# Calculated all the inputs
# Epoch: 118	 cost: 0.06255491822957993
# Calculated all the inputs
# Epoch: 119	 cost: 0.17430703341960907
# Calculated all the inputs
# Epoch: 120	 cost: 0.8045808672904968
# Calculated all the inputs
# Epoch: 121	 cost: 1.595375895500183
# Calculated all the inputs
# Epoch: 122	 cost: 0.3252634108066559
# Calculated all the inputs
# Epoch: 123	 cost: 0.6920148730278015
# Calculated all the inputs
# Epoch: 124	 cost: 2.5204966068267822
# Calculated all the inputs
# Epoch: 125	 cost: 0.34420621395111084
# Calculated all the inputs
# Epoch: 126	 cost: 1.7318390607833862
# Calculated all the inputs
# Epoch: 127	 cost: 3.299494743347168
# Calculated all the inputs
# Epoch: 128	 cost: 0.27804750204086304
# Calculated all the inputs
# Epoch: 129	 cost: 0.17374591529369354
# Calculated all the inputs
# Epoch: 130	 cost: 0.4249066710472107
# Calculated all the inputs
# Epoch: 131	 cost: 17.438385009765625
# Calculated all the inputs
# Epoch: 132	 cost: 1.60701322555542
# Calculated all the inputs
# Epoch: 133	 cost: 0.7709139585494995
# Calculated all the inputs
# Epoch: 134	 cost: 0.14469830691814423
# Calculated all the inputs
# Epoch: 135	 cost: 0.3053838610649109
# Calculated all the inputs
# Epoch: 136	 cost: 5.023589611053467
# Calculated all the inputs
# Epoch: 137	 cost: 0.5433751940727234
# Calculated all the inputs
# Epoch: 138	 cost: 0.23272864520549774
# Calculated all the inputs
# Epoch: 139	 cost: 0.21757745742797852
# Calculated all the inputs
# Epoch: 140	 cost: 0.2615329921245575
# Calculated all the inputs
# Epoch: 141	 cost: 3.852583885192871
# Calculated all the inputs
# Epoch: 142	 cost: 0.21370618045330048
# Calculated all the inputs
# Epoch: 143	 cost: 0.7224687337875366
# Calculated all the inputs
# Epoch: 144	 cost: 1.0504190921783447
# Calculated all the inputs
# Epoch: 145	 cost: 0.2388431876897812
# Calculated all the inputs
# Epoch: 146	 cost: 2.470536470413208
# Calculated all the inputs
# Epoch: 147	 cost: 0.1601664125919342
# Calculated all the inputs
# Epoch: 148	 cost: 7.7939300537109375
# Calculated all the inputs
# Epoch: 149	 cost: 0.11627797037363052
# Calculated all the inputs
# Epoch: 150	 cost: 0.1889052391052246
# Calculated all the inputs
# Epoch: 151	 cost: 0.11778654158115387
# Calculated all the inputs
# Epoch: 152	 cost: 0.2504410147666931
# Calculated all the inputs
# Epoch: 153	 cost: 0.33641254901885986
# Calculated all the inputs
# Epoch: 154	 cost: 0.5540403723716736
# Calculated all the inputs
# Epoch: 155	 cost: 0.5722136497497559
# Calculated all the inputs
# Epoch: 156	 cost: 0.1972246766090393
# Calculated all the inputs
# Epoch: 157	 cost: 0.2876558303833008
# Calculated all the inputs
# Epoch: 158	 cost: 0.3562690019607544
# Calculated all the inputs
# Epoch: 159	 cost: 0.6129078269004822
# Calculated all the inputs
# Epoch: 160	 cost: 0.1127760037779808
# Calculated all the inputs
# Epoch: 161	 cost: 0.6031932830810547
# Calculated all the inputs
# Epoch: 162	 cost: 0.2978467047214508
# Calculated all the inputs
# Epoch: 163	 cost: 0.3399597108364105
# Calculated all the inputs
# Epoch: 164	 cost: 0.6856092810630798
# Calculated all the inputs
# Epoch: 165	 cost: 1.0514650344848633
# Calculated all the inputs
# Epoch: 166	 cost: 1.8368091583251953
# Calculated all the inputs
# Epoch: 167	 cost: 0.08846555650234222
# Calculated all the inputs
# Epoch: 168	 cost: 0.3946757912635803
# Calculated all the inputs
# Epoch: 169	 cost: 0.55644690990448
# Calculated all the inputs
# Epoch: 170	 cost: 1.187290906906128
# Calculated all the inputs
# Epoch: 171	 cost: 0.17670628428459167
# Calculated all the inputs
# Epoch: 172	 cost: 0.22291415929794312
# Calculated all the inputs
# Epoch: 173	 cost: 0.331856906414032
# Calculated all the inputs
# Epoch: 174	 cost: 0.1453864574432373
# Calculated all the inputs
# Epoch: 175	 cost: 0.43781885504722595
# Calculated all the inputs
# Epoch: 176	 cost: 0.5758837461471558
# Calculated all the inputs
# Epoch: 177	 cost: 1.2093693017959595
# Calculated all the inputs
# Epoch: 178	 cost: 0.357169508934021
# Calculated all the inputs
# Epoch: 179	 cost: 0.5041177868843079
# Calculated all the inputs
# Epoch: 180	 cost: 0.07534383237361908
# Calculated all the inputs
# Epoch: 181	 cost: 3.112344980239868
# Calculated all the inputs
# Epoch: 182	 cost: 0.10867283493280411
# Calculated all the inputs
# Epoch: 183	 cost: 0.10695996880531311
# Calculated all the inputs
# Epoch: 184	 cost: 0.3238399028778076
# Calculated all the inputs
# Epoch: 185	 cost: 0.07612395286560059
# Calculated all the inputs
# Epoch: 186	 cost: 0.07113996148109436
# Calculated all the inputs
# Epoch: 187	 cost: 0.22053614258766174
# Calculated all the inputs
# Epoch: 188	 cost: 0.28623470664024353
# Calculated all the inputs
# Epoch: 189	 cost: 0.3479856550693512
# Calculated all the inputs
# Epoch: 190	 cost: 0.42378559708595276
# Calculated all the inputs
# Epoch: 191	 cost: 0.5286537408828735
# Calculated all the inputs
# Epoch: 192	 cost: 0.09347435086965561
# Calculated all the inputs
# Epoch: 193	 cost: 0.07982626557350159
# Calculated all the inputs
# Epoch: 194	 cost: 0.5059518218040466
# Calculated all the inputs
# Epoch: 195	 cost: 0.37415510416030884
# Calculated all the inputs
# Epoch: 196	 cost: 0.13576355576515198
# Calculated all the inputs
# Epoch: 197	 cost: 0.25042960047721863
# Calculated all the inputs
# Epoch: 198	 cost: 0.08658573776483536
# Calculated all the inputs
# Epoch: 199	 cost: 0.08579439669847488
# Calculated all the inputs
# Epoch: 200	 cost: 0.3270813226699829
# Calculated all the inputs
# Epoch: 201	 cost: 0.40582308173179626
# Calculated all the inputs
# Epoch: 202	 cost: 0.28262805938720703
# Calculated all the inputs
# Epoch: 203	 cost: 0.3098639249801636
# Calculated all the inputs
# Epoch: 204	 cost: 0.19714318215847015
# Calculated all the inputs
# Epoch: 205	 cost: 0.22650635242462158
# Calculated all the inputs
# Epoch: 206	 cost: 0.38480016589164734
# Calculated all the inputs
# Epoch: 207	 cost: 0.24756041169166565
# Calculated all the inputs
# Epoch: 208	 cost: 0.08786804229021072
# Calculated all the inputs
# Epoch: 209	 cost: 0.11568743735551834
# Calculated all the inputs
# Epoch: 210	 cost: 0.6847744584083557
# Calculated all the inputs
# Epoch: 211	 cost: 0.5505544543266296
# Calculated all the inputs
# Epoch: 212	 cost: 0.4558463990688324
# Calculated all the inputs
# Epoch: 213	 cost: 2.457385778427124
# Calculated all the inputs
# Epoch: 214	 cost: 0.20939882099628448
# Calculated all the inputs
# Epoch: 215	 cost: 0.9884506464004517
# Calculated all the inputs
# Epoch: 216	 cost: 0.5324472188949585
# Calculated all the inputs
# Epoch: 217	 cost: 1.3730756044387817
# Calculated all the inputs
# Epoch: 218	 cost: 0.3535483181476593
# Calculated all the inputs
# Epoch: 219	 cost: 0.3635108172893524
# Calculated all the inputs
# Epoch: 220	 cost: 0.6658962368965149
# Calculated all the inputs
# Epoch: 221	 cost: 0.5403667092323303
# Calculated all the inputs
# Epoch: 222	 cost: 0.2297348529100418
# Calculated all the inputs
# Epoch: 223	 cost: 0.9171586036682129
# Calculated all the inputs
# Epoch: 224	 cost: 0.12631860375404358
# Calculated all the inputs
# Epoch: 225	 cost: 0.3005184829235077
# Calculated all the inputs
# Epoch: 226	 cost: 0.44032007455825806
# Calculated all the inputs
# Epoch: 227	 cost: 2.6040048599243164
# Calculated all the inputs
# Epoch: 228	 cost: 0.12051698565483093
# Calculated all the inputs
# Epoch: 229	 cost: 0.17403846979141235
# Calculated all the inputs
# Epoch: 230	 cost: 0.6116774082183838
# Calculated all the inputs
# Epoch: 231	 cost: 0.5445618629455566
# Calculated all the inputs
# Epoch: 232	 cost: 0.3352317214012146
# Calculated all the inputs
# Epoch: 233	 cost: 0.5294200778007507
# Calculated all the inputs
# Epoch: 234	 cost: 0.5393132567405701
# Calculated all the inputs
# Epoch: 235	 cost: 0.6045241355895996
# Calculated all the inputs
# Epoch: 236	 cost: 0.24271130561828613
# Calculated all the inputs
# Epoch: 237	 cost: 0.7992725372314453
# Calculated all the inputs
# Epoch: 238	 cost: 0.25107595324516296
# Calculated all the inputs
# Epoch: 239	 cost: 0.06584253907203674
# Calculated all the inputs
# Epoch: 240	 cost: 0.14690697193145752
# Calculated all the inputs
# Epoch: 241	 cost: 0.24162334203720093
# Calculated all the inputs
# Epoch: 242	 cost: 0.155974879860878
# Calculated all the inputs
# Epoch: 243	 cost: 0.20202851295471191
# Calculated all the inputs
# Epoch: 244	 cost: 4.8369269371032715
# Calculated all the inputs
# Epoch: 245	 cost: 21.529796600341797
# Calculated all the inputs
# Epoch: 246	 cost: 0.8532387614250183
# Calculated all the inputs
# Epoch: 247	 cost: 0.4696033000946045
# Calculated all the inputs
# Epoch: 248	 cost: 4.5415940284729
# Calculated all the inputs
# Epoch: 249	 cost: 0.14906702935695648
# Calculated all the inputs
# Epoch: 250	 cost: 0.10467110574245453
# Calculated all the inputs
# Epoch: 251	 cost: 6.090439796447754
# Calculated all the inputs
# Epoch: 252	 cost: 0.6587855219841003
# Calculated all the inputs
# Epoch: 253	 cost: 0.11673174053430557
# Calculated all the inputs
# Epoch: 254	 cost: 0.3027973771095276
# Calculated all the inputs
# Epoch: 255	 cost: 2.199826955795288
# Calculated all the inputs
# Epoch: 256	 cost: 1.3248047828674316
# Calculated all the inputs
# Epoch: 257	 cost: 0.6579914689064026
# Calculated all the inputs
# Epoch: 258	 cost: 0.9993450045585632
# Calculated all the inputs
# Epoch: 259	 cost: 0.25519701838493347
# Calculated all the inputs
# Epoch: 260	 cost: 0.10602749139070511
# Calculated all the inputs
# Epoch: 261	 cost: 1.1114857196807861
# Calculated all the inputs
# Epoch: 262	 cost: 0.44449013471603394
# Calculated all the inputs
# Epoch: 263	 cost: 0.28563958406448364
# Calculated all the inputs
# Epoch: 264	 cost: 0.25220051407814026
# Calculated all the inputs
# Epoch: 265	 cost: 1.0039441585540771
# Calculated all the inputs
# Epoch: 266	 cost: 0.18986275792121887
# Calculated all the inputs
# Epoch: 267	 cost: 0.17663788795471191
# Calculated all the inputs
# Epoch: 268	 cost: 1.8995569944381714
# Calculated all the inputs
# Epoch: 269	 cost: 0.19308553636074066
# Calculated all the inputs
# Epoch: 270	 cost: 0.37350448966026306
# Calculated all the inputs
# Epoch: 271	 cost: 0.18095575273036957
# Calculated all the inputs
# Epoch: 272	 cost: 0.5929407477378845
# Calculated all the inputs
# Epoch: 273	 cost: 0.1695888340473175
# Calculated all the inputs
# Epoch: 274	 cost: 0.10189958661794662
# Calculated all the inputs
# Epoch: 275	 cost: 1.3059678077697754
# Calculated all the inputs
# Epoch: 276	 cost: 0.20795047283172607
# Calculated all the inputs
# Epoch: 277	 cost: 0.44381412863731384
# Calculated all the inputs
# Epoch: 278	 cost: 0.23274488747119904
# Calculated all the inputs
# Epoch: 279	 cost: 0.5076972842216492
# Calculated all the inputs
# Epoch: 280	 cost: 0.4858563542366028
# Calculated all the inputs
# Epoch: 281	 cost: 0.7376059889793396
# Calculated all the inputs
# Epoch: 282	 cost: 0.5631036162376404
# Calculated all the inputs
# Epoch: 283	 cost: 0.27274376153945923
# Calculated all the inputs
# Epoch: 284	 cost: 10.749922752380371
# Calculated all the inputs
# Epoch: 285	 cost: 0.21601472795009613
# Calculated all the inputs
# Epoch: 286	 cost: 0.27242863178253174
# Calculated all the inputs
# Epoch: 287	 cost: 0.355489045381546
# Calculated all the inputs
# Epoch: 288	 cost: 0.3721126914024353
# Calculated all the inputs
# Epoch: 289	 cost: 0.6168312430381775
# Calculated all the inputs
# Epoch: 290	 cost: 3.249002695083618
# Calculated all the inputs
# Epoch: 291	 cost: 0.9497846364974976
# Calculated all the inputs
# Epoch: 292	 cost: 0.32598087191581726
# Calculated all the inputs
# Epoch: 293	 cost: 0.28597351908683777
# Calculated all the inputs
# Epoch: 294	 cost: 0.26186683773994446
# Calculated all the inputs
# Epoch: 295	 cost: 0.676176130771637
# Calculated all the inputs
# Epoch: 296	 cost: 0.148818239569664
# Calculated all the inputs
# Epoch: 297	 cost: 0.5426268577575684
# Calculated all the inputs
# Epoch: 298	 cost: 0.5993281006813049
# Calculated all the inputs
# Epoch: 299	 cost: 0.43266257643699646
# Calculated all the inputs
# Epoch: 300	 cost: 0.4034366011619568
# Calculated all the inputs
# Epoch: 301	 cost: 0.9911900162696838
# Calculated all the inputs
# Epoch: 302	 cost: 1.071921944618225
# Calculated all the inputs
# Epoch: 303	 cost: 0.4077114164829254
# Calculated all the inputs
# Epoch: 304	 cost: 0.6765546202659607
# Calculated all the inputs
# Epoch: 305	 cost: 0.574584424495697
# Calculated all the inputs
# Epoch: 306	 cost: 1.0780303478240967
# Calculated all the inputs
# Epoch: 307	 cost: 0.38974010944366455
# Calculated all the inputs
# Epoch: 308	 cost: 1.7841442823410034
# Calculated all the inputs
# Epoch: 309	 cost: 0.19811612367630005
# Calculated all the inputs
# Epoch: 310	 cost: 0.16055427491664886
# Calculated all the inputs
# Epoch: 311	 cost: 0.11347348242998123
# Calculated all the inputs
# Epoch: 312	 cost: 2.2020578384399414
# Calculated all the inputs
# Epoch: 313	 cost: 0.7358971238136292
# Calculated all the inputs
# Epoch: 314	 cost: 0.3205764591693878
# Calculated all the inputs
# Epoch: 315	 cost: 0.4571927785873413
# Calculated all the inputs
# Epoch: 316	 cost: 0.16387873888015747
# Calculated all the inputs
# Epoch: 317	 cost: 0.2190878689289093
# Calculated all the inputs
# Epoch: 318	 cost: 0.2726175785064697
# Calculated all the inputs
# Epoch: 319	 cost: 0.180510014295578
# Calculated all the inputs
# Epoch: 320	 cost: 0.33960333466529846
# Calculated all the inputs
# Epoch: 321	 cost: 0.5727269649505615
# Calculated all the inputs
# Epoch: 322	 cost: 0.10841879993677139
# Calculated all the inputs
# Epoch: 323	 cost: 0.3612857162952423
# Calculated all the inputs
# Epoch: 324	 cost: 0.0881728082895279
# Calculated all the inputs
# Epoch: 325	 cost: 0.2576051950454712
# Calculated all the inputs
# Epoch: 326	 cost: 0.10791465640068054
# Calculated all the inputs
# Epoch: 327	 cost: 2.897792100906372
# Calculated all the inputs
# Epoch: 328	 cost: 0.21909300982952118
# Calculated all the inputs
# Epoch: 329	 cost: 0.8684719800949097
# Calculated all the inputs
# Epoch: 330	 cost: 1.8225212097167969
# Calculated all the inputs
# Epoch: 331	 cost: 0.9708971977233887
# Calculated all the inputs
# Epoch: 332	 cost: 0.3342990577220917
# Calculated all the inputs
# Epoch: 333	 cost: 0.6468392610549927
# Calculated all the inputs
# Epoch: 334	 cost: 0.6476775407791138
# Calculated all the inputs
# Epoch: 335	 cost: 0.2815622091293335
# Calculated all the inputs
# Epoch: 336	 cost: 0.07314504683017731
# Calculated all the inputs
# Epoch: 337	 cost: 0.3382508456707001
# Calculated all the inputs
# Epoch: 338	 cost: 7.477358341217041
# Calculated all the inputs
# Epoch: 339	 cost: 0.0851401835680008
# Calculated all the inputs
# Epoch: 340	 cost: 2.6821045875549316
# Calculated all the inputs
# Epoch: 341	 cost: 0.37876802682876587
# Calculated all the inputs
# Epoch: 342	 cost: 0.2265745997428894
# Calculated all the inputs
# Epoch: 343	 cost: 0.26413947343826294
# Calculated all the inputs
# Epoch: 344	 cost: 0.30905961990356445
# Calculated all the inputs
# Epoch: 345	 cost: 0.4029378890991211
# Calculated all the inputs
# Epoch: 346	 cost: 0.3040468096733093
# Calculated all the inputs
# Epoch: 347	 cost: 0.1892692893743515
# Calculated all the inputs
# Epoch: 348	 cost: 0.3722291588783264
# Calculated all the inputs
# Epoch: 349	 cost: 0.1128215566277504
# Calculated all the inputs
# Epoch: 350	 cost: 0.6945191025733948
# Calculated all the inputs
# Epoch: 351	 cost: 0.27674853801727295
# Calculated all the inputs
# Epoch: 352	 cost: 0.205111563205719
# Calculated all the inputs
# Epoch: 353	 cost: 1.3391035795211792
# Calculated all the inputs
# Epoch: 354	 cost: 0.7389127016067505
# Calculated all the inputs
# Epoch: 355	 cost: 1.68638277053833
# Calculated all the inputs
# Epoch: 356	 cost: 0.7468870282173157
# Calculated all the inputs
# Epoch: 357	 cost: 0.3573972284793854
# Calculated all the inputs
# Epoch: 358	 cost: 0.17665918171405792
# Calculated all the inputs
# Epoch: 359	 cost: 0.29043006896972656
# Calculated all the inputs
# Epoch: 360	 cost: 0.7101327180862427
# Calculated all the inputs
# Epoch: 361	 cost: 0.29332467913627625
# Calculated all the inputs
# Epoch: 362	 cost: 0.3939768970012665
# Calculated all the inputs
# Epoch: 363	 cost: 0.4735890328884125
# Calculated all the inputs
# Epoch: 364	 cost: 0.5611287951469421
# Calculated all the inputs
# Epoch: 365	 cost: 0.10250131040811539
# Calculated all the inputs
# Epoch: 366	 cost: 4.224854946136475
# Calculated all the inputs
# Epoch: 367	 cost: 0.22751390933990479
# Calculated all the inputs
# Epoch: 368	 cost: 0.32431742548942566
# Calculated all the inputs
# Epoch: 369	 cost: 0.843072235584259
# Calculated all the inputs
# Epoch: 370	 cost: 0.5768312215805054
# Calculated all the inputs
# Epoch: 371	 cost: 0.8184415102005005
# Calculated all the inputs
# Epoch: 372	 cost: 0.16055677831172943
# Calculated all the inputs
# Epoch: 373	 cost: 0.9765715599060059
# Calculated all the inputs
# Epoch: 374	 cost: 0.11404383927583694
# Calculated all the inputs
# Epoch: 375	 cost: 0.16321009397506714
# Calculated all the inputs
# Epoch: 376	 cost: 0.6406347751617432
# Calculated all the inputs
# Epoch: 377	 cost: 0.17086707055568695
# Calculated all the inputs
# Epoch: 378	 cost: 0.35907623171806335
# Calculated all the inputs
# Epoch: 379	 cost: 0.7534228563308716
# Calculated all the inputs
# Epoch: 380	 cost: 0.06619412451982498
# Calculated all the inputs
# Epoch: 381	 cost: 0.13676117360591888
# Calculated all the inputs
# Epoch: 382	 cost: 0.4521796703338623
# Calculated all the inputs
# Epoch: 383	 cost: 5.336749076843262
# Calculated all the inputs
# Epoch: 384	 cost: 0.9456074237823486
# Calculated all the inputs
# Epoch: 385	 cost: 0.6099110245704651
# Calculated all the inputs
# Epoch: 386	 cost: 0.3630671203136444
# Calculated all the inputs
# Epoch: 387	 cost: 0.8436101675033569
# Calculated all the inputs
# Epoch: 388	 cost: 0.10789640247821808
# Calculated all the inputs
# Epoch: 389	 cost: 0.45270177721977234
# Calculated all the inputs
# Epoch: 390	 cost: 0.47856950759887695
# Calculated all the inputs
# Epoch: 391	 cost: 0.419701486825943
# Calculated all the inputs
# Epoch: 392	 cost: 0.2057998776435852
# Calculated all the inputs
# Epoch: 393	 cost: 0.13923625648021698
# Calculated all the inputs
# Epoch: 394	 cost: 0.5101231336593628
# Calculated all the inputs
# Epoch: 395	 cost: 0.08994163572788239
# Calculated all the inputs
# Epoch: 396	 cost: 0.22141264379024506
# Calculated all the inputs
# Epoch: 397	 cost: 0.3649864196777344
# Calculated all the inputs
# Epoch: 398	 cost: 1.876942753791809
# Calculated all the inputs
# Epoch: 399	 cost: 0.1860583871603012
# Calculated all the inputs
# Epoch: 400	 cost: 9.146297454833984
# Calculated all the inputs
# Epoch: 401	 cost: 0.22482384741306305
# Calculated all the inputs
# Epoch: 402	 cost: 0.18477076292037964
# Calculated all the inputs
# Epoch: 403	 cost: 0.1138717532157898
# Calculated all the inputs
# Epoch: 404	 cost: 0.9853335022926331
# Calculated all the inputs
# Epoch: 405	 cost: 2.209757089614868
# Calculated all the inputs
# Epoch: 406	 cost: 7.307694911956787
# Calculated all the inputs
# Epoch: 407	 cost: 0.738512396812439
# Calculated all the inputs
# Epoch: 408	 cost: 0.9435399770736694
# Calculated all the inputs
# Epoch: 409	 cost: 0.7177635431289673
# Calculated all the inputs
# Epoch: 410	 cost: 1.7296624183654785
# Calculated all the inputs
# Epoch: 411	 cost: 0.6671854853630066
# Calculated all the inputs
# Epoch: 412	 cost: 0.2726365923881531
# Calculated all the inputs
# Epoch: 413	 cost: 6.974867343902588
# Calculated all the inputs
# Epoch: 414	 cost: 0.09238047152757645
# Calculated all the inputs
# Epoch: 415	 cost: 0.2846200168132782
# Calculated all the inputs
# Epoch: 416	 cost: 0.2649170756340027

# %%
plot_learning(cost_history)
